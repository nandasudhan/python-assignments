# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
# %matplotlib inline

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
pca = PCA(n_components=3)

# %%
X_pca = pca.fit_transform(X)

# %%
# Plot 3D scatterplot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
sns.scatterplot(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], hue=y, ax=ax)
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
ax.set_title('3D Plot of Iris Dataset')
plt.show()
# Out:
# C:\Users\Nandasudhan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nandasudhan\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:906: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if zdir == 'x':
# C:\Users\Nandasudhan\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:908: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif zdir == 'y':
# C:\Users\Nandasudhan\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:910: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif zdir[0] == '-':
